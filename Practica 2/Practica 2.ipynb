# %%
import pandas as pd

# %%
df = pd.read_csv("farm_production_dataset.csv")

# %%
df
# Out:
#        REF_DATE GEO             Type of crop  \
# 0          1908  AB                   Barley
# 1          1908  AB                 Flaxseed
# 2          1908  AB                     Oats
# 3          1908  AB                 Rye, all
# 4          1908  AB              Sugar beets
# ...         ...  ..                      ...
# 10268      1984  SK                 Tame hay
# 10269      1984  SK               Wheat, all
# 10270      1984  SK             Wheat, durum
# 10271      1984  SK            Wheat, spring
# 10272      1984  SK  Wheat, winter remaining
#
#        Average farm price (dollars per tonne)  \
# 0                                       15.00
# 1                                       29.00
# 2                                       18.00
# 3                                       23.00
# 4                                        0.55
# ...                                       ...
# 10268                                   78.00
# ...

# %%
# @title Datos estadisticos
df.describe(include='all')
# Out:
#             REF_DATE    GEO Type of crop  \
# count   10273.000000  10273        10272
# unique           NaN     14           23
# top              NaN     CA       Barley
# freq             NaN   1305          924
# mean     1947.661053    NaN          NaN
# std        22.204519    NaN          NaN
# min      1908.000000    NaN          NaN
# 25%      1929.000000    NaN          NaN
# 50%      1948.000000    NaN          NaN
# 75%      1967.000000    NaN          NaN
# max      1984.000000    NaN          NaN
#
#         Average farm price (dollars per tonne)  \
# count                             10243.000000
# unique                                     NaN
# top                                        NaN
# freq                                       NaN
# mean                                 59.633078
# std                                  90.920549
# min                                   0.000000
# 25%                                  21.000000
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
df.groupby('REF_DATE')['Production (metric tonnes)'].sum().plot()
plt.title("Grafica de produccion anual")
plt.ylabel("Produccion (toneladas metricas)")
plt.xlabel("Año")
plt.show()

# %%
# @title Area plantada con respecto a la region
average_farm_size = df.groupby('GEO')['Seeded area (hectares)'].mean()
average_farm_size
# Out:
# GEO
#        3.600000e+03
# AB     4.251739e+05
# BC     2.636036e+04
# CA     1.497098e+06
# MA     2.240093e+05
# MP     1.130102e+05
# NB     3.274571e+04
# NL     3.300000e+03
# NS     2.311406e+04
# ON     2.479951e+05
# PEI    2.329399e+04
# PP     1.630944e+06
# QU     1.770774e+05
# SK     9.514924e+05
# Name: Seeded area (hectares), dtype: float64
