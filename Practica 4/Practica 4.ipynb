# %%
import pandas as pd

# %%
df = pd.read_csv("farm_production_dataset.csv")

# %%
df
# Out:
#        REF_DATE GEO             Type of crop  \
# 0          1908  AB                   Barley
# 1          1908  AB                 Flaxseed
# 2          1908  AB                     Oats
# 3          1908  AB                 Rye, all
# 4          1908  AB              Sugar beets
# ...         ...  ..                      ...
# 10268      1984  SK                 Tame hay
# 10269      1984  SK               Wheat, all
# 10270      1984  SK             Wheat, durum
# 10271      1984  SK            Wheat, spring
# 10272      1984  SK  Wheat, winter remaining
#
#        Average farm price (dollars per tonne)  \
# 0                                       15.00
# 1                                       29.00
# 2                                       18.00
# 3                                       23.00
# 4                                        0.55
# ...                                       ...
# 10268                                   78.00
# ...

# %%
# @title Prueba de kruskal en el precio promedio de granja y su produccion

from scipy import stats

y = df['Average farm price (dollars per tonne)']
x = df['Production (metric tonnes)']

Kruskal = stats.kruskal(x,y, nan_policy='omit')
Kruskal
# Out:
# KruskalResult(statistic=np.float64(13267.029897672011), pvalue=np.float64(0.0))

# %%
# @title Prueba de kruskal en el precio promedio de granja y su rendimiento promedio

from scipy import stats

y = df['Average farm price (dollars per tonne)']
x = df['Average yield (kilograms per hectare)']

Kruskal = stats.kruskal(x,y, nan_policy='omit')
Kruskal
# Out:
# KruskalResult(statistic=np.float64(13394.365250145214), pvalue=np.float64(0.0))

# %%
# @title Prueba de kruskal en el precio promedio de granja y area plantada

from scipy import stats

y = df['Average farm price (dollars per tonne)']
x = df['Seeded area (hectares)']

Kruskal = stats.kruskal(x,y, nan_policy='omit')
Kruskal
# Out:
# KruskalResult(statistic=np.float64(12924.10412579477), pvalue=np.float64(0.0))

# %%
# @title Prueba de kruskal en el precio promedio de granja y su valor total

from scipy import stats

y = df['Average farm price (dollars per tonne)']
x = df['Total farm value (dollars)']

Kruskal = stats.kruskal(x,y, nan_policy='omit')
Kruskal
# Out:
# KruskalResult(statistic=np.float64(9999.325239043332), pvalue=np.float64(0.0))
