# %%
import pandas as pd

# %%
df = pd.read_csv("farm_production_dataset.csv")

# %%
df
# Out:
#        ref_date geo                crop_type  avg_farm_price  avg_yield  \
# 0          1908  AB                   Barley           15.00     1585.0
# 1          1908  AB                 Flaxseed           29.00      950.0
# 2          1908  AB                     Oats           18.00     1675.0
# 3          1908  AB                 Rye, all           23.00     1665.0
# 4          1908  AB              Sugar beets            0.55    18100.0
# ...         ...  ..                      ...             ...        ...
# 10268      1984  SK                 Tame hay           78.00     2870.0
# 10269      1984  SK               Wheat, all          176.00     1420.0
# 10270      1984  SK             Wheat, durum          188.00     1200.0
# 10271      1984  SK            Wheat, spring          175.00     1460.0
# 10272      1984  SK  Wheat, winter remaining          155.00     1730.0
#
#        production  seeded_area_acres  seeded_area_hectares  total_farm_value
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train = df[['total_farm_value','avg_farm_price', 'avg_yield', 'production']]
Y_train = df['ref_date']

# %%
Regresion = linear_model.LinearRegression()
Regresion.fit(X_train, Y_train)
y_pred = Regresion.predict(X_train)
print('Coefficients: \n', Regresion.coef_)
print('Independent term: \n', Regresion.intercept_)
print("Mean squared error: %.2f" % mean_squared_error(Y_train, y_pred))
print('Variance score: %.2f' % r2_score(Y_train, y_pred))

plt.scatter(X_train.iloc[:,0], Y_train,  color='black')
plt.plot(X_train.iloc[:,0], y_pred, color='blue', linewidth=3)
# Out:
# Coefficients:
#  [ 2.10823586e-05  7.48221881e-02  6.64497833e-05 -1.10796970e-06]
# Independent term:
#  1942.9203043928292
# Mean squared error: 429.25
# Variance score: 0.13
